# %% [markdown]
# <a href="https://colab.research.google.com/github/RizkyWidodo-project/IBMGraniteCourse/blob/main/United_Health_Provider_Review_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Install Package

# %%
# !pip install langchain_community
# !pip install replicate
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.3.67)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.3.26)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (3.11.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (8.5.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain_community)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.4.4)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.26->langchain_community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.26->langchain_community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (4.14.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain_community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain_community) (0.23.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain_community)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.2.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community) (2.33.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.3.1)
# Downloading langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 38.4 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 4.2 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 5.0 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain_community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.1 langchain_community-0.3.27 marshmallow-3.26.1 mypy-extensions-1.1.0 pydantic-settings-2.10.1 python-dotenv-1.1.1 typing-inspect-0.9.0
# Collecting replicate
#   Downloading replicate-1.0.7-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: httpx<1,>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from replicate) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from replicate) (24.2)
# Requirement already satisfied: pydantic>1.10.7 in /usr/local/lib/python3.11/dist-packages (from replicate) (2.11.7)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from replicate) (4.14.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.21.0->replicate) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.21.0->replicate) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.21.0->replicate) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.21.0->replicate) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.21.0->replicate) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>1.10.7->replicate) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>1.10.7->replicate) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>1.10.7->replicate) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.21.0->replicate) (1.3.1)
# Downloading replicate-1.0.7-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: replicate
# Successfully installed replicate-1.0.7

# %%
from langchain_community.llms import Replicate
import os
from google.colab import userdata

# Set the API token
api_token = userdata.get('REPLICATE_API_TOKEN')
os.environ["REPLICATE_API_TOKEN"] = api_token

# Model setup
model = "ibm-granite/granite-3.2-8b-instruct"
output = Replicate(
model=model,
replicate_api_token=api_token,
model_kwargs={"max_tokens": 1000} # Increase max_tokens
)

# %% [markdown]
# #Model Query

# %% [markdown]
# ##Load dataset

# %%
import pandas as pd

# Load the dataset from a CSV file
try:
    reviews_df = pd.read_csv('United_Review100.csv')
    customer_reviews = reviews_df['Review'].tolist()
    # Print the preview of the dataset
    print("Preview of the dataset:")
    display(reviews_df.head())
except FileNotFoundError:
    print("Error:Review File not found. Please upload the file.")
    customer_reviews = []
# Out:
# Preview of the dataset:
#    No                                             Review
# 0   1  Have not been able to access my account for a ...
# 1   2  I have been trying to obtain the 2023 fee Sche...
# 2   3  Dental and prescription cover is good. Vision ...
# 3   4  If you are looking into using All Savers Insur...
# 4   5  I have had United for several years. In Januar...

# %% [markdown]
# ##Prompting

# %%
responses = []
for i, review in enumerate(customer_reviews):
    # Refine the prompt for a single review, including examples
    Multitask_prompt = f"""
Classify the review as positive, negative, or mixed without any further explanation.
Next, identify relevant categories (only for customer service, waiting time, medical-related service satisfaction) and its each sentiment as positive, negative, or mixed
Present your response based on this format:
General Sentiment:
Aspect Sentiment:
- customer service
- waiting time
- medical-related satisfaction

Review {i+1}: {review}
"""
    # Set model parameters for prompting with adjusted values
    parameters = {
"top_k": 1,
"top_p": 0.5,
"max_tokens": 5,
"min_tokens": 0,
"random_seed": None,
"repetition_penalty": 1.5,
"stopping_criteria": "length",
"stopping_sequence": None
}
    # Invoke the model with the updated prompt for the single review
    response = output.invoke(Multitask_prompt, parameters=parameters)
    responses.append(f"Review {i+1}:\n{response}\n")

# Print all the responses
for response in responses:
    print(response)
# Out:
# Review 1:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative
# - medical-related satisfaction: N/A (not applicable)
#
# Review 2:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Mixed (implied, as the user hasn't received a response despite multiple attempts)
# - medical-related satisfaction: Not applicable (this review does not discuss medical-related service satisfaction)
#
# Review 3:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Mixed (nice, but unable to address major issues)
# - waiting time: Negative (long wait for in-person care)
# - medical-related satisfaction: Negative (dissatisfaction with vision and medical coverage, high deductibles, and virtual care recommendations)
#
# Review 4:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: N/A
# - medical-related satisfaction: Negative
#
# Review 5:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses dissatisfaction with United's outsourcing of approvals to Evicore, stating that Evicore denies everything and makes the patient appeal.
# - waiting time: Not mentioned
#   - The review does not provide information about waiting times.
# - medical-related satisfaction: Negative
#   - The reviewer is unhappy with the denial of medications they have been on for years and an MRI due to not attending therapy for at least 6 weeks, despite worsening pain.
#
# Review 6:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer had multiple negative experiences with customer service, including receiving different answers to the same questions and feeling unconfident with the representatives.
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative
#   - The reviewer was dissatisfied with the coverage of preventative care, specifically a mammogram, which was initially assured to be covered but later found not to be.
#   - The reviewer also received a bill for premiums despite being assured they were on auto-pay, indicating dissatisfaction with billing processes.
#
# Review 7:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Mixed (Negative towards the financial aspect, Neutral towards potential interaction)
# - waiting time: N/A (No information provided)
# - medical-related satisfaction: Negative (Unsatisfied with coverage and affordability of necessary surgery)
#
# Review 8:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative
#
# Review 9:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Not mentioned
# - medical-related satisfaction: Not mentioned
#
# Review 10:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative (implied by the long wait for member card and resolving medication issues)
# - medical-related satisfaction: Negative (dissatisfaction with covered services, gym membership, and eye care providers)
#
# Review 11:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Mixed (Negative due to disconnection, but positive for being transferred to a US representative)
# - medical-related satisfaction: Negative
#
# Review 12:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses dissatisfaction with the customer service, stating that the advocates are not well-trained and unable to answer simple questions.
# - waiting time: Mixed
#   - While there's no direct mention of waiting time for calls, the reviewer's frustration with the multiple errors in card generation and website/app issues could imply a perceived long wait for resolutions.
# - medical-related satisfaction: Negative
#   - The reviewer is unhappy with the medical-related service, mentioning errors in the ID card/U Card, inability to use U Card benefits, and issues with the website and app.
#
# Review 13:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The customer service agents are described as incompetent, unprofessional, and intentionally causing difficulties for customers. They are also accused of giggling in the background and hanging up on customers.
# - waiting time: Negative
#   - The reviewer mentions being put on hold for more than 30 minutes without being transferred to a U.S. agent.
# - medical-related satisfaction: Negative
#   - The review discusses issues with the UCard containing wrong doctors' information and non-functional bar codes, indicating dissatisfaction with the medical-related service.
#
# Review 14:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses dissatisfaction with the customer service, stating that it has significantly deteriorated over the years and that representatives are difficult to understand and provide inconsistent or incorrect information.
# - waiting time: Not mentioned
#   - The review does not provide any information about waiting times.
# - medical-related satisfaction: Negative
#   - The reviewer is unhappy with the explanation of benefits and the copay information provided by UHC, indicating a negative sentiment towards the medical-related service satisfaction.
#
# Review 15:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses dissatisfaction with the customer service of United Health Care, stating that they received no clear answers regarding their bill issue.
# - waiting time: Not mentioned
#   - The review does not discuss waiting times.
# - medical-related satisfaction: Negative
#   - The reviewer is unhappy with the medical-related service (glasses coverage) provided by United Health Care, stating that the actual coverage is much less than what was initially communicated and leading to a significantly higher out-of-pocket expense.
#
# Review 16:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The agent struggled to understand the customer, requiring repetition and causing frustration.
# - waiting time: Negative
#   - The customer had to wait and was put back in the queue, indicating a lengthy wait time.
# - medical-related satisfaction: Not mentioned or implied in this review.
#
# Review 17:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative
# - medical-related satisfaction: Negative
#
# Review 18:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Mixed (due to the length of the process, but no direct comment on wait times)
# - medical-related satisfaction: Negative
#
# Review 19:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative
# - medical-related satisfaction: N/A (not applicable)
#
# Review 20:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses extreme dissatisfaction with United Healthcare's customer service, stating that representatives are unhelpful, delay tactics are employed, and the company ultimately denies claims while blaming the customer for not providing correct information on time.
# - waiting time: Not mentioned
#   - The review does not provide any information regarding waiting times.
# - medical-related satisfaction: Negative
#   - The reviewer is highly dissatisfied with the medical-related service, stating that United Healthcare denied their claim despite providing necessary documents and that the company attempted to dictate the date on medical forms.
#
# Review 21:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative
# - medical-related satisfaction: Negative
#
# Review 22:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: N/A (not mentioned)
# - medical-related satisfaction: N/A (not mentioned)
#
# Review 23:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses dissatisfaction with the customer service, mentioning being left on hold for an extended period and receiving a scripted response.
# - waiting time: Negative
#   - The reviewer criticizes the long wait time on the phone.
# - medical-related satisfaction: Negative
#   - The reviewer had issues with doctors listed as in-network being rejected as out-of-network, and the claim rejection process was difficult and unsuccessful.
#
# Review 24:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   The reviewer expresses frustration and dissatisfaction with the customer service, stating that filing claims and obtaining medical supplies became a "nightmare" after switching to COBRA coverage.
# - waiting time: Not mentioned
#   There is no information about waiting times in this review.
# - medical-related satisfaction: Negative
#   The reviewer is highly dissatisfied with the medical-related service, mentioning difficulties in filing claims, additional requirements for pre-authorization, and the need for new doctor information for approved supplies.
#
# Review 25:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer had to contact United Healthcare multiple times regarding their test results, but Optum, the representative, did not get back to them.
# - waiting time: Negative
#   - The reviewer had to wait for a response from Optum after contacting them on 1/12/23.
# - medical-related satisfaction: Negative
#   - The reviewer is still waiting for the results of their Colon Cancer test, which the vendor lab received on 12/23/22. They also mentioned that United Health sent them a test kit after they had already obtained one, indicating potential confusion or mismanagement in their medical care.
#
# Review 26:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses dissatisfaction with the customer service, stating that most agents are not capable of answering questions and some lack comprehension skills.
# - waiting time: Not mentioned
#   - There is no explicit sentiment about waiting time in this review.
# - medical-related satisfaction: Negative
#   - The reviewer is unhappy with the inaccurate information provided about the Medicare Advantage plan's coverage for routine dental procedures at out-of-network dentists.
#
# Review 27:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The PBM refused to fill the prescription, indicating poor customer service.
# - waiting time: Not mentioned
#   - No information about waiting time is provided in the review.
# - medical-related satisfaction: Negative
#   - The issue with the PBM not filling the prescription suggests dissatisfaction with the medical-related service.
#
# Review 28:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses dissatisfaction with the clarity of communication from the pharmacy's customer service representatives.
# - waiting time: Not mentioned
#   - There is no information provided about the waiting time in this review.
# - medical-related satisfaction: Not mentioned
#   - There is no information provided about the medical-related service satisfaction in this review.
#
# Review 29:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Mixed (The review does not directly address customer service, but the overall dissatisfaction could be inferred as a negative sentiment towards potential customer service interactions.)
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative
#
# Review 30:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses dissatisfaction with the lack of personal communication with the doctor who denied their request.
# - waiting time: Not mentioned
#   - There is no information about the reviewer's experience with waiting times.
# - medical-related satisfaction: Negative
#   - The reviewer is unhappy with the denial of their doctor's prescribed medication and the need to appeal the decision. They also describe the insurance company as "greedy" and "unregulated."
#
# Review 31:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: N/A
# - medical-related satisfaction: N/A
#
# Review 32:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative
#
# Review 33:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: N/A
# - medical-related satisfaction: Negative
#
# Review 34:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative
#
# Review 35:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer had difficulty explaining their issue to customer service representatives and waited 30 minutes on hold to speak with a supervisor. The supervisor's response was perceived as patronizing.
# - waiting time: Negative
#   - The reviewer had to wait 30 minutes on hold to speak with a supervisor.
# - medical-related satisfaction: Negative
#   - The reviewer is unhappy with the increase in their deductible and out-of-pocket maximum, which they feel is unjustified and amounts to "theft" or a "scam." They also express dissatisfaction with the policy renewal dates and the way the increases are applied to their already met totals for the year.
#
# Review 36:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Not mentioned
# - medical-related satisfaction: Not mentioned
#
# Review 37:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative
# - medical-related satisfaction: Mixed (Negative due to claim rejections, Positive due to eventual resolution)
#
# Review 38:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer had to make multiple calls to get the prior authorization processed, and even then, it was not immediately resolved.
# - waiting time: Negative
#   - The reviewer had to wait multiple times for the prior authorization to be processed, indicating a long wait time.
# - medical-related satisfaction: Negative
#   - The reviewer was billed for more items than received, suggesting dissatisfaction with the medical service.
#
# Review 39:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative (implied, as the reviewer struggled to get in touch with anyone)
# - medical-related satisfaction: Negative (disputed claim, unexpected bill, misinformation)
#
# Review 40:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses extreme dissatisfaction with the customer service, stating it was a "nightmare" and that the process was unnecessarily time-consuming.
# - waiting time: Negative
#   - The reviewer spent 35 minutes and another 30 minutes on the phone, indicating long wait times and inefficient service.
# - medical-related satisfaction: Negative
#   - The reviewer's experience with updating their autopay information for both their Part D Rx and Supplement Part B plans was frustrating and unsuccessful, as indicated by the lack of confirmation and processed payment for the Supplement Part B plan.
#
# Review 41:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The customer experienced a significant issue with their policy approval and subsequent termination, leading to unexpected medical bills.
# - waiting time: Not mentioned
#   - No information about waiting times is provided in the review.
# - medical-related satisfaction: Negative
#   - The customer faced difficulties with their insurance coverage, resulting in uncovered medical services and substantial out-of-pocket expenses.
#
# Review 42:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative
# - medical-related satisfaction: Negative
#
# Review 43:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: N/A
# - medical-related satisfaction: Negative
#
# Review 44:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative
# - medical-related satisfaction: Not mentioned (Neutral)
#
# Review 45:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - UHC is described as extremely difficult to work with, the worst insurance company ever dealt with.
#   - There is no clear explanation of coverage when a UHC representative is asked.
#   - Multiple instances of conflicting information regarding coverage.
#   - Difficulty in getting a straight answer, being passed from department to department.
#   - UHC requests to mail claims to an American address, causing significant delays for expat members.
# - waiting time: Not mentioned
# - medical-related satisfaction: Not mentioned (but implied negatively due to overall negative sentiment)
#
# Review 46:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses extreme dissatisfaction with UHC's customer service, describing the representatives as untrained, unprofessional, and rude. They also mention long hold times, frequent disconnections, and inconsistent information from different reps.
# - waiting time: Negative
#   - The reviewer criticizes the long wait times, often exceeding 25 minutes, and the frequent disconnections during these holds.
# - medical-related satisfaction: Negative
#   - The reviewer is dissatisfied with the handling of a specific claim, describing it as being sent through "circles" and not being covered without a clear reason. They also mention dropped calls while trying to resolve the issue.
#
# Review 47:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses extreme dissatisfaction with the customer service, stating that no one knows what they're talking about and dealing with them is like "bang[ing] your head against the wall."
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative
#   - The reviewer feels they are paying out of pocket for every doctor visit despite having insurance, indicating dissatisfaction with the medical-related service. They also mention that their preferred doctors are dropping UHC due to insufficient reimbursement, further highlighting their dissatisfaction with the medical service provided.
#
# Review 48:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative
#
# Review 49:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses frustration and dissatisfaction with the customer service they received from United Healthcare, describing it as a waste of time and ineffective.
# - waiting time: Negative
#   - The reviewer mentions spending "hours and hours" on the phone with UHC, indicating a significant amount of time spent waiting for resolutions.
# - medical-related satisfaction: Mixed
#   - Initially, the reviewer expresses dissatisfaction with UHC's denial of a medically necessary procedure, leading to additional costs for the family. However, after an external appeal, the procedure was deemed medically necessary and covered, indicating a positive outcome in terms of medical-related satisfaction. Despite this, the overall sentiment towards UHC remains negative due to the prolonged struggle and perceived unethical practices.
#
# Review 50:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: N/A
# - medical-related satisfaction: Negative
#
# Review 51:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative
# - medical-related satisfaction: Negative
#
# Review 52:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses dissatisfaction with United Healthcare's customer service, stating that they delayed necessary treatment and are now denying payment, causing significant financial burden.
# - waiting time: Mixed
#   - While the reviewer mentions waiting for pre-authorization, which caused a delay in treatment, the sentiment is mixed as the delay was due to the insurance company's actions rather than an inherent issue with waiting times.
# - medical-related satisfaction: Negative
#   - The reviewer is highly dissatisfied with the medical-related service, specifically the payment and authorization process, which has led to a large bill and emotional distress during an already challenging time.
#
# Review 53:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative
# - medical-related satisfaction: Negative
#
# Review 54:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The customer service representative provided inconsistent and incorrect information about the customer's coverage. The supervisor's response was also unsatisfactory, failing to address the issue adequately.
# - waiting time: N/A (Not mentioned in the review)
# - medical-related satisfaction: Negative
#   - The customer experienced confusion and poor decision-making due to inaccurate medical coverage information provided by the customer service representatives.
#
# Review 55:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - "worse customer service"
#   - "issues and issues to be covered"
#   - "they do not care about health, they just want your money"
# - waiting time: Negative
#   - "pharmacy rush appeals will be handled in 72 hrs, and is a TOTAL lie"
#   - "a prescription that is urgent can take more than a week"
# - medical-related satisfaction: Negative
#   - "they push me and push me to change my medication after been on it for the last 8 years"
#   - "my doctor find for me 6 months of medications supplies because he got exhausted of calling (with me on the phone) with no luck to receive at least an answer"
#
# Review 56:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative
#
# Review 57:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative
#
# Review 58:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative
# - medical-related satisfaction: Not applicable (as the review focuses on customer service and waiting time, not medical service)
#
# Review 59:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative
# - medical-related satisfaction: Negative
#
# Review 60:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The review expresses dissatisfaction with UnitedHealthcare's customer service, mentioning that the doctor had to argue and fight for the necessary surgery procedure to be approved.
# - waiting time: Not mentioned
#   - The review does not provide information regarding waiting times.
# - medical-related satisfaction: Negative
#   - The reviewer is dissatisfied with the medical-related service, as the necessary surgery procedure was not initially approved, causing distress and a negative experience.
#
# Review 61:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The representative, Jaclyn, provided incorrect information.
# - waiting time: Not mentioned
#   - No information about waiting time is provided in the review.
# - medical-related satisfaction: Negative
#   - The inaccurate information led to a lack of PCP coverage for April.
#
# Review 62:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Mixed (The review doesn't directly mention customer service experiences, but the overall tone implies dissatisfaction with the service.)
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative (The user expresses extreme dissatisfaction with the medical coverage provided by the insurance.)
#
# Review 63:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses dissatisfaction with the customer service, mentioning frequent issues and denial of claims.
# - waiting time: Not mentioned
#   - There is no information provided about the waiting time.
# - medical-related satisfaction: Negative
#   - The reviewer is unhappy with the medical coverage and the process of claim denials and lack of provided summary benefit coverage.
#
# Review 64:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The customer service representative was unhelpful, left the customer on hold for an extended period without communication, and rudely hung up on them. The follow-up supervisor was unable to provide useful information and was also not available when requested.
# - waiting time: Negative
#   - The customer experienced long waiting times on hold, both with the initial representative and when requesting a supervisor.
# - medical-related satisfaction: Neutral
#   - The review does not explicitly mention satisfaction with the medical-related service itself, focusing instead on the customer service experience.
#
# Review 65:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative
#
# Review 66:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative
# - medical-related satisfaction: Negative
#
# Review 67:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The representative was argumentative.
#   - The call was disconnected after being put on hold for 13 minutes.
# - waiting time: Negative
#   - The customer had to wait for 13 minutes before the call was disconnected.
# - medical-related satisfaction: Not applicable (as the review is about being incorrectly targeted for Medicare advertising, not the medical service itself)
#
# Review 68:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The review expresses dissatisfaction with the administration staff's poor training, inconsistency, and inefficiency in handling claims and answering questions.
# - waiting time: Negative
#   - The reviewer mentions spending over 30 hours, including long calls and emails, to resolve their claims, indicating a prolonged and frustrating waiting time.
# - medical-related satisfaction: Negative
#   - The reviewer is unhappy with the claim processing, stating that only 6 out of 34 claims were initially reimbursed, and the ongoing issues with reimbursements.
#
# Review 69:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses extreme dissatisfaction with United Healthcare's customer service, describing their interactions as a "Lifetime Movie" and highlighting numerous instances of denied coverage and unhelpful responses.
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative
#   - The reviewer details multiple instances where United Healthcare denied necessary medical procedures and treatments, causing financial burden and frustration. They also mention issues with gap coverage for specialized care.
#
# Review 70:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Not mentioned
# - medical-related satisfaction: Not mentioned
#
# Review 71:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative
#
# Review 72:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - Customer service lied, gave wrong information, and hung up on the user during calls to get information.
# - waiting time: Negative
#   - The user had to wait for hours for the scheduled house call visit.
# - medical-related satisfaction: Negative
#   - United Healthcare did not cover medical expenses incurred out of state.
#   - The house call visit was not honored as promised.
#   - The appointment, initially scheduled for November 2021, was postponed to February 2022.
#   - The user did not receive the promised $70 credit card credit despite multiple complaints and calls.
#   - Dental benefits have decreased.
#   - Hearing aid coverage is no longer available.
#
# Review 73:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - Miscommunication
#   - Long wait times (56 minutes)
#   - Inefficient processes
#   - Staff admission of confusion and poor handling
# - waiting time: Negative
#   - Case marked urgent but took 14 days
#   - Multiple calls and long wait times
# - medical-related satisfaction: Negative
#   - Perceived lack of urgency in processing
#   - Additional requests for information and peer-to-peer calls causing further delays
#   - Implied poor coordination with the medical provider's office
#
# Review 74:
# General Sentiment: Positive
#
# Aspect Sentiment:
# - customer service: Positive
# - waiting time: N/A
# - medical-related satisfaction: Mixed
#
# Review 75:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses extreme dissatisfaction with the customer service, stating that they have spent over eight hours on the phone with multiple agents from various departments, yet no solution has been provided. The reviewer feels that the customer service representatives do not care about resolving the issue.
# - waiting time: Negative
#   - The reviewer mentions spending more than a week and a half trying to get in touch with customer service, indicating a long and frustrating waiting period.
# - medical-related satisfaction: Not applicable
#   - The review does not contain any information related to medical-related service satisfaction.
#
# Review 76:
# General Sentiment: Positive
#
# Aspect Sentiment:
# - customer service: Positive
# - waiting time: Not mentioned
# - medical-related satisfaction: Mixed (Positive for health encouragement, Negative for co-payments)
#
# Review 77:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Mixed (The review does not explicitly mention customer service, but the overall tone suggests dissatisfaction with the healthcare system.)
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative (The review expresses dissatisfaction with the high deductible plans, cost sharing, arbitrary denial of procedures, and the one-size-fits-all approach to healthcare.)
#
# Review 78:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   The reviewer expresses dissatisfaction with the customer service, stating that the representatives don't understand unless the situation is dire, and they lack empathy and understanding.
# - waiting time: Not mentioned
#   There's no explicit sentiment about waiting time in this review.
# - medical-related satisfaction: Negative
#   The reviewer is highly dissatisfied with the medical-related service, feeling that the professionals don't genuinely care and lack empathy. They also express a lack of trust in the system and the professionals' intentions.
#
# Review 79:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The customer has had multiple negative experiences with United Health Care's customer service, spending hours on the phone trying to resolve the issue with no success.
# - waiting time: Negative
#   - The customer has been waiting for 28 days for UHC to approve payment on their prescribed medicine, causing sleep deprivation.
# - medical-related satisfaction: Negative
#   - The customer is highly dissatisfied with the medical-related service due to the prolonged delay in receiving their prescribed medication.
#
# Review 80:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses dissatisfaction with United Health Care's customer service, stating that they refused to cover a necessary surgery despite meeting the criteria for emergency.
# - waiting time: Not mentioned
#   - The review does not provide any information about waiting times.
# - medical-related satisfaction: Negative
#   - The reviewer is highly dissatisfied with the medical-related service, as United Health Care denied coverage for a needed hernia surgery despite it meeting their own definition of an emergency.
#
# Review 81:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The user expresses dissatisfaction with the customer service, stating they spent over two hours on the phone trying to get United Health Care to pay for their dental work.
# - waiting time: Not directly mentioned, but implied negatively as the user had to pay out of pocket due to the expired contract and long phone call.
# - medical-related satisfaction: Negative
#   - The user is dissatisfied with the medical-related service, as they had to pay for dental work that should have been covered by their insurance. They also mention switching to other insurance companies, implying a lack of satisfaction with United Health Care's medical services.
#
# Review 82:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative
#
# Review 83:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative
# - medical-related satisfaction: Negative
#
# Review 84:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer has had multiple unsuccessful attempts to connect with a certified sales agent, with promises made by CSRs Rochelle, Malia, and Demi that were not followed through. The reviewer also mentions feeling frustrated and doubting UHC's genuine interest in their business.
# - waiting time: Negative
#   - The reviewer has waited for several weeks between calls and attempts to enroll without receiving the necessary assistance or callbacks.
# - medical-related satisfaction: Mixed
#   - The reviewer's sentiment towards the medical-related service (SNP plans) is mixed. While they seem interested in enrolling in a plan, their experience with UHC's customer service has been negative, potentially influencing their decision to consider competitors.
#
# Review 85:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative
# - medical-related satisfaction: Not applicable (as the review is about transportation service, not medical care)
#
# Review 86:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses frustration and dissatisfaction with the customer service representatives, stating that they have been lied to and given incorrect information.
# - waiting time: Negative
#   - The reviewer mentions that the authorization process took much longer than promised (72 hours instead of 48-72 hours), causing significant delay in the patient's surgery.
# - medical-related satisfaction: Negative
#   - The reviewer strongly criticizes the company's lack of concern for patient well-being, stating that they would never recommend the company due to their poor handling of urgent surgery authorizations.
#
# Review 87:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: N/A
# - medical-related satisfaction: N/A
#
# Review 88:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses extreme dissatisfaction with United Healthcare's customer service, describing representatives as "useless" and unable to understand English. They also mention being hung up on during a call.
# - waiting time: Not directly mentioned in the review.
# - medical-related satisfaction: Negative
#   - The reviewer is highly dissatisfied with the medical-related services, particularly the claim denials and auditing processes, which they perceive as unethical and stress-inducing.
#
# Review 89:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses dissatisfaction with the customer service, stating that representatives are unhelpful and lack knowledge.
# - waiting time: Negative
#   - The reviewer implies a negative sentiment towards waiting time, as they mention spending a significant amount of time on hold without resolution.
# - medical-related satisfaction: Negative
#   - The reviewer is highly dissatisfied with the medical-related service, citing a significant increase in out-of-pocket costs and a change in tier that has negatively impacted their coverage.
#
# Review 90:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer expresses dissatisfaction with the way United Healthcare (UHC) handles patient referrals and appeals.
# - waiting time: Negative
#   - The reviewer criticizes the long wait times for appeals, which they believe contribute to patients dying while waiting for a decision.
# - medical-related satisfaction: Negative
#   - The reviewer strongly disapproves of UHC's referral denials and their impact on patients' health and recovery, viewing it as a matter of life and death.
#
# Review 91:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - TINA S. and other UHC representatives are unhelpful, lying, and cause mental distress.
# - waiting time: Not explicitly mentioned, but implied negative due to constant crisis and suffering caused by UHC's tactics.
# - medical-related satisfaction: Negative
#   - UHC failed to provide crisis counseling, care management, and help in finding necessary medical services.
#
# Review 92:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The representative was unable to assist with the initial inquiry and provided incorrect information about the department.
# - waiting time: Negative
#   - The customer spent 45 minutes on hold and an additional 1.5 hours on subsequent attempts, with no resolution.
# - medical-related satisfaction: Not applicable (no direct mention of medical service)
#
# Review 93:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: Negative
# - medical-related satisfaction: Not applicable (as the review does not discuss medical service satisfaction)
#
# Review 94:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The customer service representative provided misleading information about the coverage of psychologist services.
# - waiting time: N/A
#   - No information about waiting time is provided in the review.
# - medical-related satisfaction: Negative
#   - The review expresses dissatisfaction with the medical service due to unexpected claim rejections and lack of clear information about coverage limits and tax ID requirements.
#
# Review 95:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
# - waiting time: N/A
# - medical-related satisfaction: Negative
#
# Review 96:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Negative
#   - The reviewer had a negative experience with customer service, feeling that they were not adequately informed about their plan coverage and had to go through multiple calls to resolve the issue.
# - waiting time: Mixed
#   - The review does not explicitly mention waiting time for calls or appointments, so it's unclear whether the reviewer had a positive or negative experience in this regard.
# - medical-related satisfaction: Negative
#   - The reviewer is dissatisfied with the medical-related service, specifically the coverage for dental extraction, which was initially promised but later denied.
#
# Review 97:
# General Sentiment: Negative
#
# Aspect Sentiment:
# - customer service: Not mentioned
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative
#
# Review 98:
# General Sentiment: Positive
#
# Aspect Sentiment:
# - customer service: Positive
# - waiting time: Not mentioned
# - medical-related satisfaction: Positive
#
# Review 99:
# General Sentiment: Positive
#
# Aspect Sentiment:
# - customer service: Positive
# - waiting time: Not mentioned
# - medical-related satisfaction: Positive
#
# Review 100:
# General Sentiment: Mixed
#
# Aspect Sentiment:
# - customer service: Not mentioned
# - waiting time: Not mentioned
# - medical-related satisfaction: Negative

# %% [markdown]
# #Turn the Response into table

# %%
import pandas as pd
import re

data = []
current_review_data = {}

def extract_simple_sentiment(sentiment_text):
    """Extracts the simple sentiment ('Positive', 'Negative', 'Mixed', 'Not mentioned')
       from the sentiment text, handling variations and case.
    """
    if pd.isna(sentiment_text):
        return 'Not mentioned'
    text = sentiment_text.lower()
    if 'positive' in text:
        return 'Positive'
    elif 'negative' in text:
        return 'Negative'
    elif 'mixed' in text:
        return 'Mixed'
    elif 'not mentioned' in text or 'n/a' in text or 'not applicable' in text:
        return 'Not mentioned'
    else:
        return 'Not mentioned' # Default for anything else


for response in responses:
    # Extract review number
    review_match = re.match(r"Review (\d+):", response)
    if review_match:
        if current_review_data: # Save previous review's data
            data.append(current_review_data)
        current_review_data = {"Review": f"Review {review_match.group(1)}"}

    # Extract General Sentiment
    general_sentiment_match = re.search(r"General Sentiment: (.+)", response)
    if general_sentiment_match:
        current_review_data["General Sentiment"] = extract_simple_sentiment(general_sentiment_match.group(1).strip())


    # Extract Aspect Sentiment
    aspect_sentiment_matches = re.findall(r"- (customer service|waiting time|medical-related satisfaction): (.+)", response)
    for aspect, sentiment in aspect_sentiment_matches:
        current_review_data[aspect.strip()] = extract_simple_sentiment(sentiment.strip())


# Add the last review's data
if current_review_data:
    data.append(current_review_data)

# Create a DataFrame
df_sentiments = pd.DataFrame(data)

# Fill missing values with 'Not mentioned' or a similar indicator
df_sentiments = df_sentiments.fillna('Not mentioned')


# Display the DataFrame
display(df_sentiments)
# Out:
#         Review General Sentiment customer service   waiting time  \
# 0     Review 1          Negative         Negative       Negative
# 1     Review 2          Negative         Negative          Mixed
# 2     Review 3          Negative            Mixed       Negative
# 3     Review 4          Negative         Negative  Not mentioned
# 4     Review 5          Negative         Negative  Not mentioned
# ..         ...               ...              ...            ...
# 95   Review 96          Negative         Negative          Mixed
# 96   Review 97          Negative    Not mentioned  Not mentioned
# 97   Review 98          Positive         Positive  Not mentioned
# 98   Review 99          Positive         Positive  Not mentioned
# 99  Review 100             Mixed    Not mentioned  Not mentioned
#
#    medical-related satisfaction
# 0                 Not mentioned
# 1                 Not mentioned
# 2                      Negative
# 3                      Negative
# 4                      Negative
# ..                          ...
# 95                     Negative
# 96                     Negative
# 97                     Positive
# 98                     Positive
# 99                     Negative
#
# [100 rows x 5 columns]

# %%
df_sentiments.to_csv('sentiment_analysis_results.csv', index=False)
